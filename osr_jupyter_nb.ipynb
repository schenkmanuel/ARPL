# %%
import os
import argparse
import datetime
import time
import csv
import pandas as pd
import importlib

import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.optim import lr_scheduler
import torch.multiprocessing as mp
import torch.backends.cudnn as cudnn
from torch.utils.data import DataLoader

from models import gan
from models.models import classifier32, classifier32ABN
from datasets.osr_dataloader import MNIST_OSR, CIFAR10_OSR, CIFAR100_OSR, SVHN_OSR, Tiny_ImageNet_OSR, VialyticsTrafficSigns_OSR
from utils import Logger, save_networks, load_networks
from core import train, train_cs, test
from class_grouping_traffic_signs import get_group, get_label_index

# %%
empty_training_classes = ['Vorgeschriebene_Fahrtrichtung_hier_links_211-10'] # folders, that do not contain training images
training_classes_with_subfolders = ['Verbot_fuer_Fahrzeuge_ueber_angegebene_tatsaechliche_Hoehe_265', 'Verbot_fuer_Fahrzeuge_ueber_angegebenes_tatsaechliches_Gewicht_262',
                                    'Verbot_fuer_Fahrzeuge_und_Zuege_ueber_angegebene_tatsaechliche_Laenge_266', 'Zusatzzeichen_weiss']


empty_test_classes = ['Sackgasse_fuer_Radverkehr_durchlaessig_357-52']  # folders, that do not contain test images
test_classes_with_subfolders = ['Verkehrszeichen_auf_anderem_Schild', 'Verbot_fuer_Fahrzeuge_ueber_angegebene_tatsaechliche_Breite_264']

# %%
options = {
    # Dataset
    'dataset': 'vialytics_traffic_signs',
    'dataroot': '/home/ec2-user/SageMaker/Traffic_Sign_Dataset_vialytics_and_GTSRB_2022_07_11',
    'num_classes': len(get_label_index(include_background_training_classes=False, include_unknown_classes=False)),
    'outf': '/home/ec2-user/SageMaker/ARPL/log',
    'out-num': 50, # help='For CIFAR100'

    # optimization
    'img-size': 128,
    'batch-size': 64,
    'lr': 0.1,
    'gan-lr': 0.0002,
    'max_epoch': 100,
    'stepsize': 30,
    'temp': 1.0,
    'num-centers': 1,

    # model
    'weight_pl': 0.1, #help="weight for center loss"
    'beta': 0.1, #help="weight for entropy loss"
    'model': 'classifier32',

    # misc
    'nz': 100,
    'ns': 1,
    'eval_freq': 1,
    'print_freq': 100,
    'gpu': '0',
    'use_cpu': False,
    'seed': 0,
    #parser.add_argument('--use-cpu', action='store_true')
    'save_dir': '../log',
    'loss': 'ARPLoss',
    'eval': False, # parser.add_argument('--eval', action='store_true', help="Eval", default=False)
    'cs': False #parser.add_argument('--cs', action='store_true', help="Confusing Sample", default=False)
}

# %%
dir_name = '{}_{}'.format(options['model'], options['loss'])
dir_path = os.path.join(options['outf'], 'results', dir_name)
if not os.path.exists(dir_path):
    os.makedirs(dir_path)

# %%
torch.manual_seed(options['seed'])
os.environ['CUDA_VISIBLE_DEVICES'] = options['gpu']
use_gpu = torch.cuda.is_available()
if options['use_cpu']: use_gpu = False
options['use_gpu'] = use_gpu
    
if use_gpu:
    print("Currently using GPU: {}".format(options['gpu']))
    cudnn.benchmark = True
    torch.cuda.manual_seed_all(options['seed'])
else:
    print("Currently using CPU")
# Out:
# Currently using GPU: 0

# %%
use_gpu
# Out:
# True

# %%
pin_memory = True if use_gpu else False
num_workers=4

traindataset = VialyticsTrafficSigns_OSR(dataroot=options['dataroot'], data_loader_type='train', empty_classes=empty_training_classes, 
                                         classes_with_subfolders=training_classes_with_subfolders, img_size=options['img-size'])
trainloader = DataLoader(traindataset, batch_size=options['batch-size'], shuffle=True, num_workers=num_workers, pin_memory=pin_memory)

testdataset = VialyticsTrafficSigns_OSR(dataroot=options['dataroot'], data_loader_type='test', empty_classes=[], classes_with_subfolders=[], img_size=options['img-size'])
testloader = DataLoader(testdataset, batch_size=options['batch-size'], shuffle=False, num_workers=num_workers, pin_memory=pin_memory)

outdataset = VialyticsTrafficSigns_OSR(dataroot=options['dataroot'], data_loader_type='out', empty_classes=empty_test_classes, classes_with_subfolders=test_classes_with_subfolders, 
                                       img_size=options['img-size'])
outloader = DataLoader(testdataset, batch_size=options['batch-size'], shuffle=False, num_workers=num_workers, pin_memory=pin_memory)

# %%
# for imgs, labels in trainloader:
#     print(imgs)
#     print(labels)
#     break

# %%
# Model
print("Creating model: {}".format(options['model']))
if options['cs']:
    net = classifier32ABN(num_classes=options['num_classes'])
else:
    net = classifier32(num_classes=options['num_classes'])
feat_dim = 128

if options['cs']:
    print("Creating GAN")
    nz, ns = options['nz'], 1
    if 'tiny_imagenet' in options['dataset']:
        netG = gan.Generator(1, nz, 64, 3)
        netD = gan.Discriminator(1, 3, 64)
    else:
        netG = gan.Generator32(1, nz, 64, 3)
        netD = gan.Discriminator32(1, 3, 64)
    fixed_noise = torch.FloatTensor(64, nz, 1, 1).normal_(0, 1)
    criterionD = nn.BCELoss()
# Out:
# Creating model: classifier32

# %%
# Loss
options.update(
    {
        'feat_dim': feat_dim,
        'use_gpu':  use_gpu
    }
)

Loss = importlib.import_module('loss.'+options['loss'])
criterion = getattr(Loss, options['loss'])(**options)

if use_gpu:
    net = nn.DataParallel(net).cuda()
    criterion = criterion.cuda()
    if options['cs']:
        netG = nn.DataParallel(netG, device_ids=[i for i in range(len(options['gpu'].split(',')))]).cuda()
        netD = nn.DataParallel(netD, device_ids=[i for i in range(len(options['gpu'].split(',')))]).cuda()
        fixed_noise.cuda()

model_path = os.path.join(options['outf'], 'models', options['dataset'])
if not os.path.exists(model_path):
    os.makedirs(model_path)

# %%
file_name = '{}_{}_{}'.format(options['model'], options['loss'], options['cs'])

params_list = [{'params': net.parameters()},
            {'params': criterion.parameters()}]

if options['dataset'] in ['tiny_imagenet', 'vialytics_traffic_signs']:
    optimizer = torch.optim.Adam(params_list, lr=options['lr'])
else:
    optimizer = torch.optim.SGD(params_list, lr=options['lr'], momentum=0.9, weight_decay=1e-4)
if options['cs']:
    optimizerD = torch.optim.Adam(netD.parameters(), lr=options['gan_lr'], betas=(0.5, 0.999))
    optimizerG = torch.optim.Adam(netG.parameters(), lr=options['gan_lr'], betas=(0.5, 0.999))

if options['stepsize'] > 0:
    scheduler = lr_scheduler.MultiStepLR(optimizer, milestones=[30,60,90,120])

# %%
training_progress = open(os.path.join(options['outf'], 'training_progress.txt'), 'w')

start_time = time.time()

for epoch in range(options['max_epoch']):
    print("==> Epoch {}/{}".format(epoch+1, options['max_epoch']))
    # paste training progress to file, because sagemaker often looses server connection, but still trains in the background
    with open(os.path.join(options['outf'], 'training_progress.txt'), 'a') as f:
        f.write("\n")
        f.write(f"==> Epoch {epoch+1}/{options['max_epoch']}")

    if options['cs']:
        train_cs(net, netD, netG, criterion, criterionD,
            optimizer, optimizerD, optimizerG,
            trainloader, epoch=epoch, **options)

    train(net, criterion, optimizer, trainloader, epoch=epoch, **options)

    if options['eval_freq'] > 0 and (epoch+1) % options['eval_freq'] == 0 or (epoch+1) == options['max_epoch']:
        print("==> Test", options['loss'])
        # paste training progress to file, because sagemaker often looses server connection, but still trains in the background
#         with open(os.path.join(options['outf'], 'training_progress.txt'), 'a') as f:
#             f.write("\n")
#             f.write(f"==> Test, {options['loss']}")
            
    
        results = test(net, criterion, testloader, outloader, epoch=epoch, **options)
        print("Acc (%): {:.3f}\t AUROC (%): {:.3f}\t OSCR (%): {:.3f}\t".format(results['ACC'], results['AUROC'], results['OSCR']))
        
        # paste training progress to file, because sagemaker often looses server connection, but still trains in the background
        with open(os.path.join(options['outf'], 'training_progress.txt'), 'a') as f:
            f.write("\n")
            f.write("Acc (%): {:.3f}\t AUROC (%): {:.3f}\t OSCR (%): {:.3f}\t".format(results['ACC'], results['AUROC'], results['OSCR']))

        save_networks(net, model_path, str(epoch)+'_'+str(round(results['ACC'], 3)), criterion=criterion)

    if options['stepsize'] > 0: scheduler.step()

elapsed = round(time.time() - start_time)
elapsed = str(datetime.timedelta(seconds=elapsed))
print("Finished. Total elapsed time (h:m:s): {}".format(elapsed))
# paste training progress to file, because sagemaker often looses server connection, but still trains in the background
with open(os.path.join(options['outf'], 'training_progress.txt'), 'a') as f:
    f.write("\n")
    f.write("Finished. Total elapsed time (h:m:s): {}".format(elapsed))

df = pd.DataFrame(results)
df.to_csv(os.path.join(dir_path, file_name))
# Out:
# ==> Epoch 1/100
# Batch 100/1482	 Loss 3.778719 (3.702163)
# Batch 200/1482	 Loss 3.213026 (3.547456)
# Batch 300/1482	 Loss 2.981953 (3.453630)
# Batch 400/1482	 Loss 3.316528 (3.389215)
# Batch 500/1482	 Loss 3.193722 (3.336328)
# Batch 600/1482	 Loss 3.312529 (3.293527)
# Batch 700/1482	 Loss 3.234801 (3.243996)
# Batch 800/1482	 Loss 2.977823 (3.196497)
# Batch 900/1482	 Loss 2.925632 (3.153650)
# Batch 1000/1482	 Loss 2.685591 (3.116610)
# Batch 1100/1482	 Loss 2.328896 (3.081428)
# Batch 1200/1482	 Loss 2.038402 (3.040014)
# Batch 1300/1482	 Loss 2.549214 (3.000491)
# Batch 1400/1482	 Loss 2.408072 (2.963069)
# ==> Test ARPLoss
# Acc: 40.32227
#        TNR    AUROC  DTACC  AUIN   AUOUT
# Bas     4.987 49.995 50.000 49.987 49.987
# Acc (%): 40.322	 AUROC (%): 49.995	 OSCR (%): 26.467
# ==> Epoch 2/100
# Batch 100/1482	 Loss 2.321947 (2.359645)
# Batch 200/1482	 Loss 2.184645 (2.343234)
# Batch 300/1482	 Loss 1.633160 (2.250832)
# Batch 400/1482	 Loss 1.811486 (2.184373)
# Batch 500/1482	 Loss 1.789421 (2.098077)
# Batch 600/1482	 Loss 1.444289 (2.022659)
# Batch 700/1482	 Loss 1.228544 (1.948655)
# Batch 800/1482	 Loss 1.362705 (1.896205)
# Batch 900/1482	 Loss 1.501421 (1.839366)
# Batch 1000/1482	 Loss 1.658502 (1.792334)
# Batch 1100/1482	 Loss 1.125645 (1.745680)
# Batch 1200/1482	 Loss 1.302604 (1.703752)
# Batch 1300/1482	 Loss 1.085265 (1.663630)
# Batch 1400/1482	 Loss 1.064036 (1.626759)
# ==> Test ARPLoss
# Acc: 55.34897
#        TNR    AUROC  DTACC  AUIN   AUOUT
# Bas     4.987 49.995 50.000 49.987 49.987
# Acc (%): 55.349	 AUROC (%): 49.995	 OSCR (%): 35.257
# ==> Epoch 3/100
# Batch 100/1482	 Loss 0.789103 (1.064902)
# Batch 200/1482	 Loss 1.127150 (1.038569)
# Batch 300/1482	 Loss 1.077474 (1.039486)
# Batch 400/1482	 Loss 1.125456 (1.025684)
# Batch 500/1482	 Loss 1.236733 (1.002845)
# Batch 600/1482	 Loss 0.671354 (0.975635)
# Batch 700/1482	 Loss 1.107451 (0.958780)
# Batch 800/1482	 Loss 0.906358 (0.943060)
# Batch 900/1482	 Loss 0.668488 (0.927152)
# Batch 1000/1482	 Loss 0.669170 (0.917294)
# Batch 1100/1482	 Loss 0.506535 (0.904643)
# Batch 1200/1482	 Loss 1.016837 (0.889047)
# Batch 1300/1482	 Loss 0.762530 (0.876167)
# Batch 1400/1482	 Loss 0.716975 (0.863510)
# ==> Test ARPLoss
# Acc: 78.57551
#        TNR    AUROC  DTACC  AUIN   AUOUT
# Bas     4.987 49.995 50.000 49.987 49.987
# Acc (%): 78.576	 AUROC (%): 49.995	 OSCR (%): 44.938
# ==> Epoch 4/100
# Batch 100/1482	 Loss 0.760452 (0.678497)
# Batch 200/1482	 Loss 0.510411 (0.678775)
# Batch 300/1482	 Loss 0.341878 (0.673818)
# Batch 400/1482	 Loss 0.479070 (0.651033)
# Batch 500/1482	 Loss 0.539930 (0.643718)
# Batch 600/1482	 Loss 0.732455 (0.639436)
# Batch 700/1482	 Loss 0.737432 (0.643276)
# Batch 800/1482	 Loss 0.769322 (0.634240)
# Batch 900/1482	 Loss 0.478970 (0.633805)
# Batch 1000/1482	 Loss 0.546875 (0.632636)
# Batch 1100/1482	 Loss 0.767151 (0.632512)
# Batch 1200/1482	 Loss 0.714744 (0.629173)
# Batch 1300/1482	 Loss 0.369617 (0.623638)
# Batch 1400/1482	 Loss 0.374562 (0.619006)
# ==> Test ARPLoss
# Acc: 62.17582
#        TNR    AUROC  DTACC  AUIN   AUOUT
# Bas     4.987 49.995 50.000 49.987 49.987
# Acc (%): 62.176	 AUROC (%): 49.995	 OSCR (%): 36.671
# ==> Epoch 5/100
# Batch 100/1482	 Loss 0.425381 (0.506555)
# Batch 200/1482	 Loss 1.029209 (0.516491)
# Batch 300/1482	 Loss 0.699126 (0.525768)
# Batch 400/1482	 Loss 0.622140 (0.520196)
# Batch 500/1482	 Loss 0.503227 (0.526178)
# Batch 600/1482	 Loss 0.387209 (0.520908)
# Batch 700/1482	 Loss 0.421499 (0.517002)
# Batch 800/1482	 Loss 0.582743 (0.511877)
# Batch 900/1482	 Loss 0.394555 (0.511191)
# Batch 1000/1482	 Loss 0.442074 (0.509750)
# Batch 1100/1482	 Loss 0.334822 (0.508615)
# Batch 1200/1482	 Loss 0.941336 (0.509210)
# Batch 1300/1482	 Loss 0.556241 (0.508120)
# Batch 1400/1482	 Loss 0.882539 (0.507000)
# ==> Test ARPLoss
# Acc: 77.13577
#        TNR    AUROC  DTACC  AUIN   AUOUT
# Bas     4.987 49.995 50.000 49.987 49.987
# Acc (%): 77.136	 AUROC (%): 49.995	 OSCR (%): 43.718
# ==> Epoch 6/100
# Batch 100/1482	 Loss 0.235455 (0.451136)
# Batch 200/1482	 Loss 0.359118 (0.448394)
# Batch 300/1482	 Loss 0.549151 (0.452757)
# Batch 400/1482	 Loss 0.799853 (0.451035)
# Batch 500/1482	 Loss 0.768144 (0.439983)
# Batch 600/1482	 Loss 0.139741 (0.438282)
# Batch 700/1482	 Loss 0.268919 (0.439483)
# Batch 800/1482	 Loss 0.459460 (0.443527)
# Batch 900/1482	 Loss 0.410491 (0.440459)
# Batch 1000/1482	 Loss 0.568992 (0.438617)
# Batch 1100/1482	 Loss 0.432976 (0.437939)
# Batch 1200/1482	 Loss 0.595773 (0.435556)
# Batch 1300/1482	 Loss 0.233852 (0.436096)
# Batch 1400/1482	 Loss 0.340414 (0.437290)
# ==> Test ARPLoss
# Acc: 79.84363
#        TNR    AUROC  DTACC  AUIN   AUOUT
# Bas     4.987 49.995 50.000 49.987 49.987
# Acc (%): 79.844	 AUROC (%): 49.995	 OSCR (%): 44.963
# ==> Epoch 7/100
# Batch 100/1482	 Loss 0.310870 (0.414191)
# Batch 200/1482	 Loss 0.454348 (0.411078)
# Batch 300/1482	 Loss 0.359235 (0.406346)
# Batch 400/1482	 Loss 0.263307 (0.399322)
# Batch 500/1482	 Loss 0.219939 (0.391506)
# Batch 600/1482	 Loss 0.434472 (0.394937)
# Batch 700/1482	 Loss 0.277506 (0.394197)
# Batch 800/1482	 Loss 0.581765 (0.389861)
# Batch 900/1482	 Loss 0.216127 (0.387378)
# Batch 1000/1482	 Loss 0.160128 (0.387508)
# Batch 1100/1482	 Loss 0.651958 (0.389290)
# Batch 1200/1482	 Loss 0.362100 (0.387463)
# Batch 1300/1482	 Loss 0.592780 (0.385886)
# Batch 1400/1482	 Loss 0.346530 (0.381577)
# ==> Test ARPLoss
# Acc: 84.72540
#        TNR    AUROC  DTACC  AUIN   AUOUT
# Bas     4.987 49.995 50.000 49.987 49.987
# Acc (%): 84.725	 AUROC (%): 49.995	 OSCR (%): 45.628
# ==> Epoch 8/100
# Batch 100/1482	 Loss 0.293928 (0.387456)
# Batch 200/1482	 Loss 0.613127 (0.390269)
# Batch 300/1482	 Loss 0.137895 (0.373619)
# Batch 400/1482	 Loss 0.275813 (0.367317)
# Batch 500/1482	 Loss 0.361166 (0.372023)
# Batch 600/1482	 Loss 0.487053 (0.374292)
# Batch 700/1482	 Loss 0.415215 (0.374300)
# Batch 800/1482	 Loss 0.163677 (0.375354)
# Batch 900/1482	 Loss 0.362520 (0.376243)
# Batch 1000/1482	 Loss 0.265162 (0.376833)
# Batch 1100/1482	 Loss 0.331528 (0.377845)
# Batch 1200/1482	 Loss 0.633283 (0.375721)
# Batch 1300/1482	 Loss 0.185047 (0.372502)
# Batch 1400/1482	 Loss 0.273402 (0.372113)
# ==> Test ARPLoss
# Acc: 89.50229
#        TNR    AUROC  DTACC  AUIN   AUOUT
# Bas     4.987 49.995 50.000 49.987 49.987
# Acc (%): 89.502	 AUROC (%): 49.995	 OSCR (%): 48.161
# ==> Epoch 9/100
# Batch 100/1482	 Loss 0.171912 (0.321918)
# Batch 200/1482	 Loss 0.410620 (0.331650)
# Batch 300/1482	 Loss 0.362232 (0.322556)
# Batch 400/1482	 Loss 0.169125 (0.319484)
# Batch 500/1482	 Loss 0.216094 (0.322570)
# Batch 600/1482	 Loss 0.234391 (0.325086)
# Batch 700/1482	 Loss 0.478508 (0.323527)
# Batch 800/1482	 Loss 0.145624 (0.328235)
# Batch 900/1482	 Loss 0.204087 (0.328944)
# Batch 1000/1482	 Loss 0.193335 (0.326997)
# Batch 1100/1482	 Loss 0.450686 (0.327144)
# Batch 1200/1482	 Loss 0.297692 (0.326756)
# Batch 1300/1482	 Loss 0.255234 (0.325913)
# Batch 1400/1482	 Loss 0.277877 (0.326566)
# ==> Test ARPLoss
# Acc: 90.58924
#        TNR    AUROC  DTACC  AUIN   AUOUT
# Bas     4.987 49.995 50.000 49.987 49.987
# Acc (%): 90.589	 AUROC (%): 49.995	 OSCR (%): 48.074
# ==> Epoch 10/100
# Batch 100/1482	 Loss 0.298213 (0.333419)
# Batch 200/1482	 Loss 0.361719 (0.324813)
# Batch 300/1482	 Loss 0.444155 (0.345813)
# Batch 400/1482	 Loss 0.337646 (0.337481)
# Batch 500/1482	 Loss 0.539479 (0.334972)
# Batch 600/1482	 Loss 0.536808 (0.328532)
# Batch 700/1482	 Loss 0.443466 (0.327518)
# Batch 800/1482	 Loss 0.505659 (0.327426)
# Batch 900/1482	 Loss 0.191851 (0.322218)
# Batch 1000/1482	 Loss 0.318866 (0.320563)
# Batch 1100/1482	 Loss 0.735654 (0.319307)
# Batch 1200/1482	 Loss 0.382659 (0.318323)
# Batch 1300/1482	 Loss 0.293122 (0.319289)
# Batch 1400/1482	 Loss 0.238435 (0.319392)
# ==> Test ARPLoss
# Acc: 89.09230
#        TNR    AUROC  DTACC  AUIN   AUOUT
# Bas     4.987 49.995 50.000 49.987 49.987
# Acc (%): 89.092	 AUROC (%): 49.995	 OSCR (%): 46.948
# ==> Epoch 11/100
# Batch 100/1482	 Loss 0.618743 (0.323849)
# Batch 200/1482	 Loss 0.459965 (0.304718)
# Batch 300/1482	 Loss 0.229473 (0.296510)
# Batch 400/1482	 Loss 0.431637 (0.287895)
# Batch 500/1482	 Loss 0.390706 (0.286729)
# Batch 600/1482	 Loss 0.333600 (0.293230)
# Batch 700/1482	 Loss 0.408895 (0.289541)
# Batch 800/1482	 Loss 0.421434 (0.287402)
# Batch 900/1482	 Loss 0.600131 (0.285955)
# Batch 1000/1482	 Loss 0.309111 (0.286297)
# Batch 1100/1482	 Loss 0.222530 (0.284809)
# Batch 1200/1482	 Loss 0.235290 (0.283454)
# Batch 1300/1482	 Loss 0.481007 (0.286597)
# Batch 1400/1482	 Loss 0.280524 (0.285440)
# ==> Test ARPLoss
# Acc: 74.73303
#        TNR    AUROC  DTACC  AUIN   AUOUT
# Bas     4.987 49.995 50.000 49.987 49.987
# Acc (%): 74.733	 AUROC (%): 49.995	 OSCR (%): 40.174
# ==> Epoch 12/100
# Batch 100/1482	 Loss 0.045471 (0.304797)
# Batch 200/1482	 Loss 0.276298 (0.308033)
# Batch 300/1482	 Loss 0.288293 (0.298283)
# Batch 400/1482	 Loss 0.146804 (0.287060)
# Batch 500/1482	 Loss 0.435092 (0.272979)
# Batch 600/1482	 Loss 0.491479 (0.269381)
# Batch 700/1482	 Loss 0.311791 (0.273252)
# Batch 800/1482	 Loss 0.407630 (0.277113)
# Batch 900/1482	 Loss 0.267491 (0.276113)
# Batch 1000/1482	 Loss 0.707245 (0.277184)
# Batch 1100/1482	 Loss 0.239713 (0.275014)
# Batch 1200/1482	 Loss 0.184810 (0.271549)
# Batch 1300/1482	 Loss 0.122670 (0.272546)
# Batch 1400/1482	 Loss 0.083489 (0.277883)
# ==> Test ARPLoss
# Acc: 90.98017
#        TNR    AUROC  DTACC  AUIN   AUOUT
# Bas     4.987 49.995 50.000 49.987 49.987
# Acc (%): 90.980	 AUROC (%): 49.995	 OSCR (%): 47.991
# ==> Epoch 13/100
# Batch 100/1482	 Loss 0.576583 (0.309404)
# Batch 200/1482	 Loss 0.305986 (0.288036)
# Batch 300/1482	 Loss 0.285436 (0.301096)
# Batch 400/1482	 Loss 0.280816 (0.297073)
# Batch 500/1482	 Loss 0.253761 (0.290525)
# Batch 600/1482	 Loss 0.589684 (0.293604)
# Batch 700/1482	 Loss 0.149233 (0.292671)
# Batch 800/1482	 Loss 0.632106 (0.290566)
# Batch 900/1482	 Loss 0.125410 (0.287407)
# Batch 1000/1482	 Loss 0.290960 (0.285881)
# Batch 1100/1482	 Loss 0.045962 (0.282430)
# Batch 1200/1482	 Loss 0.548342 (0.284277)
# Batch 1300/1482	 Loss 0.907041 (0.284966)
# Batch 1400/1482	 Loss 0.324565 (0.284168)
# ==> Test ARPLoss
# Acc: 87.76697
#        TNR    AUROC  DTACC  AUIN   AUOUT
# Bas     4.987 49.995 50.000 49.987 49.987
# Acc (%): 87.767	 AUROC (%): 49.995	 OSCR (%): 47.130
# ==> Epoch 14/100
# Batch 100/1482	 Loss 0.527376 (0.276448)
# Batch 200/1482	 Loss 0.323913 (0.260968)
# Batch 300/1482	 Loss 0.132561 (0.256994)
# Batch 400/1482	 Loss 0.538719 (0.256790)
# Batch 500/1482	 Loss 0.175446 (0.258443)
# Batch 600/1482	 Loss 0.457735 (0.257351)
# Batch 700/1482	 Loss 0.162266 (0.253802)
# Batch 800/1482	 Loss 0.115692 (0.255449)
# Batch 900/1482	 Loss 0.319300 (0.250689)
# Batch 1000/1482	 Loss 0.290594 (0.250227)
# Batch 1100/1482	 Loss 0.178942 (0.257573)
# Batch 1200/1482	 Loss 0.155841 (0.257186)
# Batch 1300/1482	 Loss 0.344177 (0.257346)
# Batch 1400/1482	 Loss 0.098587 (0.255377)
# ==> Test ARPLoss
# Acc: 92.55339
#        TNR    AUROC  DTACC  AUIN   AUOUT
# Bas     4.987 49.995 50.000 49.987 49.987
# Acc (%): 92.553	 AUROC (%): 49.995	 OSCR (%): 48.810
# ==> Epoch 15/100
# Batch 100/1482	 Loss 0.263318 (0.260508)
# Batch 200/1482	 Loss 0.536949 (0.263880)
# Batch 300/1482	 Loss 0.256373 (0.260577)
# Batch 400/1482	 Loss 0.410936 (0.266502)
# Batch 500/1482	 Loss 0.698649 (0.271717)
# Batch 600/1482	 Loss 0.326668 (0.276965)
# Batch 700/1482	 Loss 0.119838 (0.278266)
# Batch 800/1482	 Loss 0.175389 (0.274204)
# Batch 900/1482	 Loss 0.036038 (0.277672)
# Batch 1000/1482	 Loss 0.342310 (0.274998)
# Batch 1100/1482	 Loss 0.241096 (0.270542)
# Batch 1200/1482	 Loss 0.294481 (0.267134)
# Batch 1300/1482	 Loss 0.246699 (0.265603)
# Batch 1400/1482	 Loss 0.121716 (0.265601)
# ==> Test ARPLoss
# Acc: 93.81198
#        TNR    AUROC  DTACC  AUIN   AUOUT
# Bas     4.987 49.995 50.000 49.987 49.987
# Acc (%): 93.812	 AUROC (%): 49.995	 OSCR (%): 49.033
# ==> Epoch 16/100
# Batch 100/1482	 Loss 0.167997 (0.275642)
# Batch 200/1482	 Loss 0.251602 (0.249695)
# Batch 300/1482	 Loss 0.430290 (0.233896)
# Batch 400/1482	 Loss 0.554422 (0.231248)
# Batch 500/1482	 Loss 0.278274 (0.231283)
# Batch 600/1482	 Loss 0.168720 (0.232536)
# Batch 700/1482	 Loss 0.088124 (0.236865)
# Batch 800/1482	 Loss 0.434172 (0.241315)
# Batch 900/1482	 Loss 0.178957 (0.244619)
# Batch 1000/1482	 Loss 0.354750 (0.249245)
# Batch 1100/1482	 Loss 0.108340 (0.248783)
# Batch 1200/1482	 Loss 0.283185 (0.250924)
# Batch 1300/1482	 Loss 0.438848 (0.254639)
# Batch 1400/1482	 Loss 0.220980 (0.258341)
# ==> Test ARPLoss
# Acc: 92.24828
#        TNR    AUROC  DTACC  AUIN   AUOUT
# Bas     4.987 49.995 50.000 49.987 49.987
# Acc (%): 92.248	 AUROC (%): 49.995	 OSCR (%): 48.416
# ==> Epoch 17/100
# Batch 100/1482	 Loss 0.458120 (0.226925)
# Batch 200/1482	 Loss 0.319541 (0.221666)
# Batch 300/1482	 Loss 0.263683 (0.238964)
# Batch 400/1482	 Loss 0.087861 (0.244105)
# Batch 500/1482	 Loss 0.436844 (0.246730)
# Batch 600/1482	 Loss 0.358350 (0.242051)
# Batch 700/1482	 Loss 0.174010 (0.236008)
# Batch 800/1482	 Loss 0.063414 (0.235103)
# Batch 900/1482	 Loss 0.286399 (0.232922)
# Batch 1000/1482	 Loss 0.535246 (0.236602)
# Batch 1100/1482	 Loss 0.071170 (0.236729)
# Batch 1200/1482	 Loss 0.177053 (0.237056)
# Batch 1300/1482	 Loss 0.215744 (0.238278)
# Batch 1400/1482	 Loss 0.281623 (0.237546)
# ==> Test ARPLoss
# Acc: 91.44737
#        TNR    AUROC  DTACC  AUIN   AUOUT
# Bas     4.987 49.995 50.000 49.987 49.987
# Acc (%): 91.447	 AUROC (%): 49.995	 OSCR (%): 48.525
# ==> Epoch 18/100
# Batch 100/1482	 Loss 0.281850 (0.279860)
# Batch 200/1482	 Loss 0.244150 (0.267345)
# Batch 300/1482	 Loss 0.840809 (0.259065)
# Batch 400/1482	 Loss 0.052287 (0.255161)
# Batch 500/1482	 Loss 0.173474 (0.252259)
# Batch 600/1482	 Loss 0.179269 (0.251080)
# Batch 700/1482	 Loss 0.071703 (0.256773)
# Batch 800/1482	 Loss 0.657609 (0.252290)
# Batch 900/1482	 Loss 0.192039 (0.249878)
# Batch 1000/1482	 Loss 0.321752 (0.249070)
# Batch 1100/1482	 Loss 0.390599 (0.247048)
# Batch 1200/1482	 Loss 0.038845 (0.246217)
# Batch 1300/1482	 Loss 0.104515 (0.244951)
# Batch 1400/1482	 Loss 0.266355 (0.245646)
# ==> Test ARPLoss
# Acc: 93.22082
#        TNR    AUROC  DTACC  AUIN   AUOUT
# Bas     4.987 49.995 50.000 49.987 49.987
# Acc (%): 93.221	 AUROC (%): 49.995	 OSCR (%): 48.716
# ==> Epoch 19/100
# Batch 100/1482	 Loss 0.123090 (0.279158)
# Batch 200/1482	 Loss 0.041376 (0.244916)
# Batch 300/1482	 Loss 0.271127 (0.232561)
# Batch 400/1482	 Loss 0.175790 (0.223756)
# Batch 500/1482	 Loss 0.139265 (0.217531)
# Batch 600/1482	 Loss 0.173879 (0.223199)
# Batch 700/1482	 Loss 0.064108 (0.227777)
# Batch 800/1482	 Loss 0.097886 (0.230478)
# Batch 900/1482	 Loss 0.398630 (0.230529)
# Batch 1000/1482	 Loss 0.202193 (0.228165)
# Batch 1100/1482	 Loss 0.192296 (0.228996)
# Batch 1200/1482	 Loss 0.009110 (0.228022)
# Batch 1300/1482	 Loss 0.034079 (0.226984)
# Batch 1400/1482	 Loss 0.094871 (0.226690)
# ==> Test ARPLoss
# Acc: 93.35431
#        TNR    AUROC  DTACC  AUIN   AUOUT
# Bas     4.987 49.995 50.000 49.987 49.987
# Acc (%): 93.354	 AUROC (%): 49.995	 OSCR (%): 48.540
# ==> Epoch 20/100
# Batch 100/1482	 Loss 0.420013 (0.229151)
# Batch 200/1482	 Loss 0.088610 (0.236972)
# Batch 300/1482	 Loss 0.386970 (0.233359)
# Batch 400/1482	 Loss 0.011725 (0.232371)
# Batch 500/1482	 Loss 0.675237 (0.233152)
# Batch 600/1482	 Loss 0.220473 (0.234266)
# Batch 700/1482	 Loss 0.059429 (0.237848)
# Batch 800/1482	 Loss 0.226707 (0.238107)
# Batch 900/1482	 Loss 0.138914 (0.236997)
# Batch 1000/1482	 Loss 0.256205 (0.238065)
# Batch 1100/1482	 Loss 0.132183 (0.236620)
# Batch 1200/1482	 Loss 0.126242 (0.236466)
# Batch 1300/1482	 Loss 0.289347 (0.235367)
# Batch 1400/1482	 Loss 0.281876 (0.233830)
# ==> Test ARPLoss
# Acc: 90.32227
#        TNR    AUROC  DTACC  AUIN   AUOUT
# Bas     4.987 49.995 50.000 49.987 49.987
# Acc (%): 90.322	 AUROC (%): 49.995	 OSCR (%): 46.756
# ==> Epoch 21/100
# Batch 100/1482	 Loss 0.081368 (0.250505)
# Batch 200/1482	 Loss 0.402382 (0.238716)
# Batch 300/1482	 Loss 0.134091 (0.231134)
# Batch 400/1482	 Loss 0.250663 (0.219555)
# Batch 500/1482	 Loss 0.227919 (0.217433)
# Batch 600/1482	 Loss 0.431225 (0.221097)
# Batch 700/1482	 Loss 0.386808 (0.224316)
# Batch 800/1482	 Loss 0.314723 (0.224645)
# Batch 900/1482	 Loss 0.521545 (0.227917)
# Batch 1000/1482	 Loss 0.301219 (0.227076)
# Batch 1100/1482	 Loss 0.475722 (0.227764)
# Batch 1200/1482	 Loss 0.073988 (0.230468)
# Batch 1300/1482	 Loss 0.189501 (0.230538)
# Batch 1400/1482	 Loss 0.397199 (0.231308)
# ==> Test ARPLoss
# Acc: 93.95500
#        TNR    AUROC  DTACC  AUIN   AUOUT
# Bas     4.987 49.995 50.000 49.987 49.987
# Acc (%): 93.955	 AUROC (%): 49.995	 OSCR (%): 48.942
# ==> Epoch 22/100
# Batch 100/1482	 Loss 0.253177 (0.184753)
# Batch 200/1482	 Loss 0.313444 (0.209292)
# Batch 300/1482	 Loss 0.141130 (0.225929)
# Batch 400/1482	 Loss 0.254068 (0.226682)
# Batch 500/1482	 Loss 0.222576 (0.221033)
# Batch 600/1482	 Loss 0.457873 (0.219697)
# Batch 700/1482	 Loss 0.070492 (0.218074)
# Batch 800/1482	 Loss 0.037052 (0.213569)
# Batch 900/1482	 Loss 0.503013 (0.219603)
# Batch 1000/1482	 Loss 0.401576 (0.220223)
# Batch 1100/1482	 Loss 0.280729 (0.225707)
# Batch 1200/1482	 Loss 0.072016 (0.227958)
# Batch 1300/1482	 Loss 0.174293 (0.226835)
# Batch 1400/1482	 Loss 0.081697 (0.225326)
# ==> Test ARPLoss
# Acc: 91.11365
#        TNR    AUROC  DTACC  AUIN   AUOUT
# Bas     4.987 49.995 50.000 49.987 49.987
# Acc (%): 91.114	 AUROC (%): 49.995	 OSCR (%): 48.147
# ==> Epoch 23/100
# Batch 100/1482	 Loss 0.232348 (0.190323)
# Batch 200/1482	 Loss 0.292075 (0.193284)
# Batch 300/1482	 Loss 0.125809 (0.189167)
# Batch 400/1482	 Loss 0.138917 (0.200143)
# Batch 500/1482	 Loss 0.036432 (0.199669)
# Batch 600/1482	 Loss 0.196313 (0.202137)
# Batch 700/1482	 Loss 0.063968 (0.202227)
# Batch 800/1482	 Loss 0.291551 (0.201122)
# Batch 900/1482	 Loss 0.126900 (0.201259)
# Batch 1000/1482	 Loss 0.212414 (0.203950)
# Batch 1100/1482	 Loss 0.320839 (0.205033)
# Batch 1200/1482	 Loss 0.076015 (0.205365)
# Batch 1300/1482	 Loss 0.119155 (0.202669)
# Batch 1400/1482	 Loss 0.110575 (0.206809)
# ==> Test ARPLoss
# Acc: 95.09916
#        TNR    AUROC  DTACC  AUIN   AUOUT
# Bas     4.987 49.995 50.000 49.987 49.987
# Acc (%): 95.099	 AUROC (%): 49.995	 OSCR (%): 49.188
# ==> Epoch 24/100
# Batch 100/1482	 Loss 0.187670 (0.210143)
# Batch 200/1482	 Loss 0.342590 (0.200199)
# Batch 300/1482	 Loss 0.263647 (0.204070)
# Batch 400/1482	 Loss 0.134568 (0.209301)
# Batch 500/1482	 Loss 0.419113 (0.215164)
# Batch 600/1482	 Loss 0.329983 (0.213583)
# Batch 700/1482	 Loss 0.141595 (0.211500)
# Batch 800/1482	 Loss 0.259325 (0.215671)
# Batch 900/1482	 Loss 0.456403 (0.216050)
# Batch 1000/1482	 Loss 0.403263 (0.217270)
# Batch 1100/1482	 Loss 0.185249 (0.216694)
# Batch 1200/1482	 Loss 0.219806 (0.218013)
# Batch 1300/1482	 Loss 0.374118 (0.217651)
# Batch 1400/1482	 Loss 0.107569 (0.217795)
# ==> Test ARPLoss
# Acc: 94.72731
#        TNR    AUROC  DTACC  AUIN   AUOUT
# Bas     4.987 49.995 50.000 49.987 49.987
# Acc (%): 94.727	 AUROC (%): 49.995	 OSCR (%): 49.068
# ==> Epoch 25/100
# Batch 100/1482	 Loss 0.108829 (0.186642)
# Batch 200/1482	 Loss 0.020247 (0.197504)
# Batch 300/1482	 Loss 0.224834 (0.210077)
# Batch 400/1482	 Loss 0.230985 (0.212544)
# Batch 500/1482	 Loss 0.506679 (0.209185)
# Batch 600/1482	 Loss 0.018593 (0.208113)
# Batch 700/1482	 Loss 0.146051 (0.205771)
# Batch 800/1482	 Loss 0.289292 (0.205012)
# Batch 900/1482	 Loss 0.170647 (0.206779)
# Batch 1000/1482	 Loss 0.173151 (0.208018)
# Batch 1100/1482	 Loss 0.530848 (0.209085)
# Batch 1200/1482	 Loss 0.241318 (0.209119)
# Batch 1300/1482	 Loss 0.627555 (0.208774)
# Batch 1400/1482	 Loss 0.204480 (0.206474)
# ==> Test ARPLoss
# Acc: 92.72502
#        TNR    AUROC  DTACC  AUIN   AUOUT
# Bas     4.987 49.995 50.000 49.987 49.987
# Acc (%): 92.725	 AUROC (%): 49.995	 OSCR (%): 48.170
# ==> Epoch 26/100
# Batch 100/1482	 Loss 0.476158 (0.198521)
# Batch 200/1482	 Loss 0.256462 (0.206099)
# Batch 300/1482	 Loss 0.070131 (0.215824)
# Batch 400/1482	 Loss 0.093801 (0.216231)
# Batch 500/1482	 Loss 0.116545 (0.224773)
# Batch 600/1482	 Loss 0.061982 (0.220864)
# Batch 700/1482	 Loss 0.304402 (0.227777)
# Batch 800/1482	 Loss 0.319385 (0.226550)
# Batch 900/1482	 Loss 0.028374 (0.218898)
# Batch 1000/1482	 Loss 0.224759 (0.214158)
# Batch 1100/1482	 Loss 0.128230 (0.214044)
# Batch 1200/1482	 Loss 0.382611 (0.214438)
# Batch 1300/1482	 Loss 0.212833 (0.213121)
# Batch 1400/1482	 Loss 0.286096 (0.215018)
# ==> Test ARPLoss
# Acc: 94.44127
#        TNR    AUROC  DTACC  AUIN   AUOUT
# Bas     4.987 49.995 50.000 49.987 49.987
# Acc (%): 94.441	 AUROC (%): 49.995	 OSCR (%): 48.838
# ==> Epoch 27/100
# Batch 100/1482	 Loss 0.174716 (0.247381)
# Batch 200/1482	 Loss 0.096682 (0.217860)
# Batch 300/1482	 Loss 0.394816 (0.205799)
# Batch 400/1482	 Loss 0.128985 (0.200937)
# Batch 500/1482	 Loss 0.360825 (0.196577)
# Batch 600/1482	 Loss 0.736260 (0.202286)
# Batch 700/1482	 Loss 0.380470 (0.201016)
# Batch 800/1482	 Loss 0.099449 (0.196311)
# Batch 900/1482	 Loss 0.106338 (0.190443)
# Batch 1000/1482	 Loss 0.129002 (0.188904)
# Batch 1100/1482	 Loss 0.074926 (0.188092)
# Batch 1200/1482	 Loss 0.105971 (0.188866)
# Batch 1300/1482	 Loss 0.184631 (0.188579)
# Batch 1400/1482	 Loss 0.105907 (0.189097)
# ==> Test ARPLoss
# Acc: 94.79405
#        TNR    AUROC  DTACC  AUIN   AUOUT
# Bas     4.987 49.995 50.000 49.987 49.987
# Acc (%): 94.794	 AUROC (%): 49.995	 OSCR (%): 49.014
# ==> Epoch 28/100
# Batch 100/1482	 Loss 0.004253 (0.214815)
# Batch 200/1482	 Loss 0.152370 (0.218488)
# Batch 300/1482	 Loss 0.190406 (0.216567)
# Batch 400/1482	 Loss 0.292826 (0.217436)
# Batch 500/1482	 Loss 0.208895 (0.217541)
# Batch 600/1482	 Loss 0.157208 (0.213157)
# Batch 700/1482	 Loss 0.104455 (0.216889)
# Batch 800/1482	 Loss 0.433613 (0.220926)
# Batch 900/1482	 Loss 0.310513 (0.220374)
# Batch 1000/1482	 Loss 0.224115 (0.220710)
# Batch 1100/1482	 Loss 0.205667 (0.218809)
# Batch 1200/1482	 Loss 0.123590 (0.218075)
# Batch 1300/1482	 Loss 0.337617 (0.218200)
# Batch 1400/1482	 Loss 0.155031 (0.217762)
# ==> Test ARPLoss
# Acc: 93.84058
#        TNR    AUROC  DTACC  AUIN   AUOUT
# Bas     4.987 49.995 50.000 49.987 49.987
# Acc (%): 93.841	 AUROC (%): 49.995	 OSCR (%): 48.832
# ==> Epoch 29/100
# Batch 100/1482	 Loss 0.021533 (0.180397)
# Batch 200/1482	 Loss 0.003897 (0.178739)
# Batch 300/1482	 Loss 0.420264 (0.177111)
# Batch 400/1482	 Loss 0.346346 (0.182352)
# Batch 500/1482	 Loss 0.355460 (0.184831)
# Batch 600/1482	 Loss 0.214634 (0.190413)
# Batch 700/1482	 Loss 0.119608 (0.192653)
# Batch 800/1482	 Loss 0.207349 (0.195315)
# Batch 900/1482	 Loss 0.552750 (0.194656)
# Batch 1000/1482	 Loss 0.058816 (0.194598)
# Batch 1100/1482	 Loss 0.078602 (0.194167)
# Batch 1200/1482	 Loss 0.021261 (0.193365)
# Batch 1300/1482	 Loss 0.263781 (0.197809)
# Batch 1400/1482	 Loss 0.252857 (0.199594)
# ==> Test ARPLoss
# Acc: 93.92639
#        TNR    AUROC  DTACC  AUIN   AUOUT
# Bas     4.987 49.995 50.000 49.987 49.987
# Acc (%): 93.926	 AUROC (%): 49.995	 OSCR (%): 48.850
# ==> Epoch 30/100
# Batch 100/1482	 Loss 0.212161 (0.197819)
# Batch 200/1482	 Loss 0.261538 (0.198466)
# Batch 300/1482	 Loss 0.099611 (0.206034)
# Batch 400/1482	 Loss 0.258232 (0.205330)
# Batch 500/1482	 Loss 0.127958 (0.207192)
# Batch 600/1482	 Loss 0.055054 (0.202561)
# Batch 700/1482	 Loss 0.057591 (0.204396)
# Batch 800/1482	 Loss 0.076967 (0.206210)
# Batch 900/1482	 Loss 0.625122 (0.209273)
# Batch 1000/1482	 Loss 0.216842 (0.205119)
# Batch 1100/1482	 Loss 0.518633 (0.204377)
# Batch 1200/1482	 Loss 0.115085 (0.204026)
# Batch 1300/1482	 Loss 0.235128 (0.204198)
# Batch 1400/1482	 Loss 0.195384 (0.202919)
# ==> Test ARPLoss
# Acc: 92.03852
#        TNR    AUROC  DTACC  AUIN   AUOUT
# Bas     4.987 49.995 50.000 49.987 49.987
# Acc (%): 92.039	 AUROC (%): 49.995	 OSCR (%): 48.286
# ==> Epoch 31/100
# Batch 100/1482	 Loss 0.026850 (0.129912)
# Batch 200/1482	 Loss 0.101001 (0.115216)
# Batch 300/1482	 Loss 0.068663 (0.100622)
# Batch 400/1482	 Loss 0.040141 (0.093996)
# Batch 500/1482	 Loss 0.053225 (0.091652)
# Batch 600/1482	 Loss 0.109234 (0.092336)
# Batch 700/1482	 Loss 0.200891 (0.091809)
# Batch 800/1482	 Loss 0.037986 (0.090414)
# Batch 900/1482	 Loss 0.086592 (0.090195)
# Batch 1000/1482	 Loss 0.046249 (0.089303)
# Batch 1100/1482	 Loss 0.077154 (0.088611)
# Batch 1200/1482	 Loss 0.046632 (0.086859)
# Batch 1300/1482	 Loss 0.185276 (0.086152)
# Batch 1400/1482	 Loss 0.150997 (0.084218)
# ==> Test ARPLoss
# Acc: 97.54005
#        TNR    AUROC  DTACC  AUIN   AUOUT
# Bas     4.987 49.995 50.000 49.987 49.987
# Acc (%): 97.540	 AUROC (%): 49.995	 OSCR (%): 49.554
# ==> Epoch 32/100
# Batch 100/1482	 Loss 0.081764 (0.078510)
# Batch 200/1482	 Loss 0.001015 (0.077739)
# Batch 300/1482	 Loss 0.024100 (0.074851)
# Batch 400/1482	 Loss 0.004156 (0.073019)
# Batch 500/1482	 Loss 0.002122 (0.070657)
# Batch 600/1482	 Loss 0.070737 (0.069757)
# Batch 700/1482	 Loss 0.017672 (0.073180)
# Batch 800/1482	 Loss 0.003965 (0.074034)
# Batch 900/1482	 Loss 0.184719 (0.074854)
# Batch 1000/1482	 Loss 0.068818 (0.075097)
# Batch 1100/1482	 Loss 0.030149 (0.074303)
# Batch 1200/1482	 Loss 0.030956 (0.074052)
# Batch 1300/1482	 Loss 0.086050 (0.073930)
# Batch 1400/1482	 Loss 0.075330 (0.072841)
# ==> Test ARPLoss
# Acc: 97.70214
#        TNR    AUROC  DTACC  AUIN   AUOUT
# Bas     4.987 49.995 50.000 49.987 49.987
# Acc (%): 97.702	 AUROC (%): 49.995	 OSCR (%): 49.655
# ==> Epoch 33/100
# Batch 100/1482	 Loss 0.064570 (0.061920)
# Batch 200/1482	 Loss 0.070884 (0.064284)
# Batch 300/1482	 Loss 0.040947 (0.065404)
# Batch 400/1482	 Loss 0.002545 (0.067328)
# Batch 500/1482	 Loss 0.007500 (0.066463)
# Batch 600/1482	 Loss 0.001572 (0.065701)
# Batch 700/1482	 Loss 0.076829 (0.065377)
# Batch 800/1482	 Loss 0.065119 (0.066118)
# Batch 900/1482	 Loss 0.293514 (0.066463)
# Batch 1000/1482	 Loss 0.144613 (0.067157)
# Batch 1100/1482	 Loss 0.019350 (0.068337)
# Batch 1200/1482	 Loss 0.015723 (0.067817)
# Batch 1300/1482	 Loss 0.071767 (0.067502)
# Batch 1400/1482	 Loss 0.155431 (0.066997)
# ==> Test ARPLoss
# Acc: 97.78795
#        TNR    AUROC  DTACC  AUIN   AUOUT
# Bas     4.987 49.995 50.000 49.987 49.987
# Acc (%): 97.788	 AUROC (%): 49.995	 OSCR (%): 49.538
# ==> Epoch 34/100
# Batch 100/1482	 Loss 0.047553 (0.059055)
# Batch 200/1482	 Loss 0.009919 (0.063861)
# Batch 300/1482	 Loss 0.138797 (0.067294)
# Batch 400/1482	 Loss 0.005962 (0.064563)
# Batch 500/1482	 Loss 0.002151 (0.064668)
# Batch 600/1482	 Loss 0.003555 (0.063391)
# Batch 700/1482	 Loss 0.000612 (0.063223)
# Batch 800/1482	 Loss 0.051008 (0.062009)
# Batch 900/1482	 Loss 0.030822 (0.063425)
# Batch 1000/1482	 Loss 0.000321 (0.063644)
# Batch 1100/1482	 Loss 0.068517 (0.063755)
# Batch 1200/1482	 Loss 0.146904 (0.063633)
# Batch 1300/1482	 Loss 0.349153 (0.063771)
# Batch 1400/1482	 Loss 0.037510 (0.064238)
# ==> Test ARPLoss
# Acc: 97.83562
#        TNR    AUROC  DTACC  AUIN   AUOUT
# Bas     4.987 49.995 50.000 49.987 49.987
# Acc (%): 97.836	 AUROC (%): 49.995	 OSCR (%): 49.591
# ==> Epoch 35/100
# Batch 100/1482	 Loss 0.021388 (0.069041)
# Batch 200/1482	 Loss 0.030572 (0.063126)
# Batch 300/1482	 Loss 0.071890 (0.063259)
# Batch 400/1482	 Loss 0.078275 (0.061601)
# Batch 500/1482	 Loss 0.073655 (0.063018)
# Batch 600/1482	 Loss 0.003023 (0.060738)
# Batch 700/1482	 Loss 0.034613 (0.060024)
# Batch 800/1482	 Loss 0.125246 (0.059213)
# Batch 900/1482	 Loss 0.083114 (0.060364)
# Batch 1000/1482	 Loss 0.000704 (0.060393)
# Batch 1100/1482	 Loss 0.004901 (0.060070)
# Batch 1200/1482	 Loss 0.067368 (0.060192)
# Batch 1300/1482	 Loss 0.063777 (0.060366)
# Batch 1400/1482	 Loss 0.060737 (0.061015)
# ==> Test ARPLoss
# Acc: 97.89283
#        TNR    AUROC  DTACC  AUIN   AUOUT
# Bas     4.987 49.995 50.000 49.987 49.987
# Acc (%): 97.893	 AUROC (%): 49.995	 OSCR (%): 49.538
# ==> Epoch 36/100
# Batch 100/1482	 Loss 0.225187 (0.061304)
# Batch 200/1482	 Loss 0.025983 (0.061062)
# Batch 300/1482	 Loss 0.048733 (0.060545)
# Batch 400/1482	 Loss 0.074124 (0.064622)
# Batch 500/1482	 Loss 0.007323 (0.063591)
# Batch 600/1482	 Loss 0.060270 (0.064010)
# Batch 700/1482	 Loss 0.062064 (0.064337)
# Batch 800/1482	 Loss 0.245294 (0.063962)
# Batch 900/1482	 Loss 0.155421 (0.064534)
# Batch 1000/1482	 Loss 0.048402 (0.064077)
# Batch 1100/1482	 Loss 0.000194 (0.064229)
# Batch 1200/1482	 Loss 0.106135 (0.063189)
# Batch 1300/1482	 Loss 0.000923 (0.062530)
# Batch 1400/1482	 Loss 0.000445 (0.062544)
# ==> Test ARPLoss
# Acc: 98.06445
#        TNR    AUROC  DTACC  AUIN   AUOUT
# Bas     4.987 49.995 50.000 49.987 49.987
# Acc (%): 98.064	 AUROC (%): 49.995	 OSCR (%): 49.558
# ==> Epoch 37/100
# Batch 100/1482	 Loss 0.001815 (0.060338)
# Batch 200/1482	 Loss 0.124037 (0.056814)
# Batch 300/1482	 Loss 0.023251 (0.056920)
# Batch 400/1482	 Loss 0.000529 (0.059322)
# Batch 500/1482	 Loss 0.002882 (0.059988)
# Batch 600/1482	 Loss 0.083702 (0.059797)
# Batch 700/1482	 Loss 0.038720 (0.059452)
# Batch 800/1482	 Loss 0.000091 (0.060333)
# Batch 900/1482	 Loss 0.001862 (0.058735)
# Batch 1000/1482	 Loss 0.023975 (0.059011)
# Batch 1100/1482	 Loss 0.002665 (0.059956)
# Batch 1200/1482	 Loss 0.045655 (0.059502)
# Batch 1300/1482	 Loss 0.043868 (0.059758)
# Batch 1400/1482	 Loss 0.039838 (0.059760)
# ==> Test ARPLoss
# Acc: 97.82609
#        TNR    AUROC  DTACC  AUIN   AUOUT
# Bas     4.987 49.995 50.000 49.987 49.987
# Acc (%): 97.826	 AUROC (%): 49.995	 OSCR (%): 49.586
# ==> Epoch 38/100
# Batch 100/1482	 Loss 0.122201 (0.053617)
# Batch 200/1482	 Loss 0.096732 (0.061492)
# Batch 300/1482	 Loss 0.005120 (0.059581)
# Batch 400/1482	 Loss 0.075438 (0.060595)
# Batch 500/1482	 Loss 0.001960 (0.060458)
# Batch 600/1482	 Loss 0.198824 (0.059354)
# Batch 700/1482	 Loss 0.032916 (0.059723)
# Batch 800/1482	 Loss 0.201455 (0.060292)
# Batch 900/1482	 Loss 0.114925 (0.061408)
# Batch 1000/1482	 Loss 0.008161 (0.061787)
# Batch 1100/1482	 Loss 0.105414 (0.060998)
# Batch 1200/1482	 Loss 0.001264 (0.060821)
# Batch 1300/1482	 Loss 0.117187 (0.061550)
# Batch 1400/1482	 Loss 0.082355 (0.060977)
# ==> Test ARPLoss
# Acc: 98.10259
#        TNR    AUROC  DTACC  AUIN   AUOUT
# Bas     4.987 49.995 50.000 49.987 49.987
# Acc (%): 98.103	 AUROC (%): 49.995	 OSCR (%): 49.601
# ==> Epoch 39/100
# Batch 100/1482	 Loss 0.007832 (0.050422)
# Batch 200/1482	 Loss 0.035660 (0.056946)
# Batch 300/1482	 Loss 0.007329 (0.060154)
# Batch 400/1482	 Loss 0.033884 (0.058490)
# Batch 500/1482	 Loss 0.003194 (0.056012)
# Batch 600/1482	 Loss 0.119655 (0.055856)
# Batch 700/1482	 Loss 0.008656 (0.056279)
# Batch 800/1482	 Loss 0.004391 (0.057000)
# Batch 900/1482	 Loss 0.034254 (0.057879)
# Batch 1000/1482	 Loss 0.118974 (0.058344)
# Batch 1100/1482	 Loss 0.021078 (0.059338)
# Batch 1200/1482	 Loss 0.002297 (0.059656)
# Batch 1300/1482	 Loss 0.180679 (0.060456)
# Batch 1400/1482	 Loss 0.017993 (0.060754)
# ==> Test ARPLoss
# Acc: 97.62586
#        TNR    AUROC  DTACC  AUIN   AUOUT
# Bas     4.987 49.995 50.000 49.987 49.987
# Acc (%): 97.626	 AUROC (%): 49.995	 OSCR (%): 49.554
# ==> Epoch 40/100
# Batch 100/1482	 Loss 0.035273 (0.066192)
# Batch 200/1482	 Loss 0.185970 (0.060567)
# Batch 300/1482	 Loss 0.020481 (0.059953)
# Batch 400/1482	 Loss 0.056974 (0.061767)
# Batch 500/1482	 Loss 0.001553 (0.059587)
# Batch 600/1482	 Loss 0.204355 (0.058344)
# Batch 700/1482	 Loss 0.037740 (0.058055)
# Batch 800/1482	 Loss 0.048745 (0.058032)
# Batch 900/1482	 Loss 0.008683 (0.057901)
# Batch 1000/1482	 Loss 0.010253 (0.058074)
# Batch 1100/1482	 Loss 0.533698 (0.057491)
# Batch 1200/1482	 Loss 0.002126 (0.058284)
# Batch 1300/1482	 Loss 0.004466 (0.057911)
# Batch 1400/1482	 Loss 0.052038 (0.057946)
# ==> Test ARPLoss
# Acc: 98.14073
#        TNR    AUROC  DTACC  AUIN   AUOUT
# Bas     4.987 49.995 50.000 49.987 49.987
# Acc (%): 98.141	 AUROC (%): 49.995	 OSCR (%): 49.639
# ==> Epoch 41/100
# Batch 100/1482	 Loss 0.104599 (0.054546)
# Batch 200/1482	 Loss 0.007393 (0.056536)
# Batch 300/1482	 Loss 0.002446 (0.054998)
# Batch 400/1482	 Loss 0.005903 (0.053777)
# Batch 500/1482	 Loss 0.005345 (0.054454)
# Batch 600/1482	 Loss 0.000354 (0.056420)
# Batch 700/1482	 Loss 0.002323 (0.056521)
# Batch 800/1482	 Loss 0.056006 (0.056416)
# Batch 900/1482	 Loss 0.164336 (0.057001)
# Batch 1000/1482	 Loss 0.005388 (0.057571)
# Batch 1100/1482	 Loss 0.003935 (0.058018)
# Batch 1200/1482	 Loss 0.048386 (0.057456)
# Batch 1300/1482	 Loss 0.006574 (0.057705)
# Batch 1400/1482	 Loss 0.095923 (0.058306)
# ==> Test ARPLoss
# Acc: 97.95004
#        TNR    AUROC  DTACC  AUIN   AUOUT
# Bas     4.987 49.995 50.000 49.987 49.987
# Acc (%): 97.950	 AUROC (%): 49.995	 OSCR (%): 49.589
# ==> Epoch 42/100
# Batch 100/1482	 Loss 0.077703 (0.052153)
# Batch 200/1482	 Loss 0.003500 (0.052811)
# Batch 300/1482	 Loss 0.067038 (0.053342)
# Batch 400/1482	 Loss 0.120201 (0.055013)
# Batch 500/1482	 Loss 0.073756 (0.054805)
# Batch 600/1482	 Loss 0.088526 (0.055273)
# Batch 700/1482	 Loss 0.052131 (0.055430)
# Batch 800/1482	 Loss 0.019677 (0.055091)
# Batch 900/1482	 Loss 0.154399 (0.056638)
# Batch 1000/1482	 Loss 0.000591 (0.056310)
# Batch 1100/1482	 Loss 0.041019 (0.056575)
# Batch 1200/1482	 Loss 0.127109 (0.057260)
# Batch 1300/1482	 Loss 0.001029 (0.056808)
# Batch 1400/1482	 Loss 0.084766 (0.057007)
# ==> Test ARPLoss
# Acc: 98.09306
#        TNR    AUROC  DTACC  AUIN   AUOUT
# Bas     4.987 49.995 50.000 49.987 49.987
# Acc (%): 98.093	 AUROC (%): 49.995	 OSCR (%): 49.641
# ==> Epoch 43/100
# Batch 100/1482	 Loss 0.052288 (0.058998)
# Batch 200/1482	 Loss 0.001785 (0.055155)
# Batch 300/1482	 Loss 0.000390 (0.056607)
# Batch 400/1482	 Loss 0.008199 (0.057475)
# Batch 500/1482	 Loss 0.006352 (0.056463)
# Batch 600/1482	 Loss 0.063832 (0.055760)
# Batch 700/1482	 Loss 0.013019 (0.054970)
# Batch 800/1482	 Loss 0.022006 (0.054546)
# Batch 900/1482	 Loss 0.011762 (0.055526)
# Batch 1000/1482	 Loss 0.002844 (0.054832)
# Batch 1100/1482	 Loss 0.107583 (0.054935)
# Batch 1200/1482	 Loss 0.091383 (0.055561)
# Batch 1300/1482	 Loss 0.001920 (0.055775)
# Batch 1400/1482	 Loss 0.085367 (0.055810)
# ==> Test ARPLoss
# Acc: 97.92143
#        TNR    AUROC  DTACC  AUIN   AUOUT
# Bas     4.987 49.995 50.000 49.987 49.987
# Acc (%): 97.921	 AUROC (%): 49.995	 OSCR (%): 49.612
# ==> Epoch 44/100
# Batch 100/1482	 Loss 0.026199 (0.047206)
# Batch 200/1482	 Loss 0.001243 (0.052030)
# Batch 300/1482	 Loss 0.004101 (0.056578)
# Batch 400/1482	 Loss 0.152687 (0.055708)
# Batch 500/1482	 Loss 0.005546 (0.054381)
# Batch 600/1482	 Loss 0.003356 (0.054703)
# Batch 700/1482	 Loss 0.059943 (0.055626)
# Batch 800/1482	 Loss 0.219578 (0.055593)
# Batch 900/1482	 Loss 0.147576 (0.057117)
# Batch 1000/1482	 Loss 0.006826 (0.056235)
# Batch 1100/1482	 Loss 0.000473 (0.057421)
# Batch 1200/1482	 Loss 0.002463 (0.057443)
# Batch 1300/1482	 Loss 0.007328 (0.057037)
# Batch 1400/1482	 Loss 0.001146 (0.057384)
# ==> Test ARPLoss
# Acc: 97.98818
#        TNR    AUROC  DTACC  AUIN   AUOUT
# Bas     4.987 49.995 50.000 49.987 49.987
# Acc (%): 97.988	 AUROC (%): 49.995	 OSCR (%): 49.606
# ==> Epoch 45/100
# Batch 100/1482	 Loss 0.014220 (0.072397)
# Batch 200/1482	 Loss 0.026466 (0.065933)
# Batch 300/1482	 Loss 0.003363 (0.061667)
# Batch 400/1482	 Loss 0.005032 (0.059451)
# Batch 500/1482	 Loss 0.001096 (0.058969)
# Batch 600/1482	 Loss 0.007983 (0.058170)
# Batch 700/1482	 Loss 0.001684 (0.059041)
# Batch 800/1482	 Loss 0.156020 (0.059699)
# Batch 900/1482	 Loss 0.189783 (0.059181)
# Batch 1000/1482	 Loss 0.008427 (0.058730)
# Batch 1100/1482	 Loss 0.069477 (0.059467)
# Batch 1200/1482	 Loss 0.006688 (0.059382)
# Batch 1300/1482	 Loss 0.125857 (0.058102)
# Batch 1400/1482	 Loss 0.001750 (0.058141)
# ==> Test ARPLoss
# Acc: 97.94050
#        TNR    AUROC  DTACC  AUIN   AUOUT
# Bas     4.987 49.995 50.000 49.987 49.987
# Acc (%): 97.941	 AUROC (%): 49.995	 OSCR (%): 49.572
# ==> Epoch 46/100
# Batch 100/1482	 Loss 0.005008 (0.060780)
# Batch 200/1482	 Loss 0.157451 (0.061681)
# Batch 300/1482	 Loss 0.005910 (0.058385)
# Batch 400/1482	 Loss 0.104503 (0.059752)
# Batch 500/1482	 Loss 0.001372 (0.056623)
# Batch 600/1482	 Loss 0.186872 (0.057242)
# Batch 700/1482	 Loss 0.006454 (0.056014)
# Batch 800/1482	 Loss 0.094837 (0.056684)
# Batch 900/1482	 Loss 0.001519 (0.055977)
# Batch 1000/1482	 Loss 0.004306 (0.056364)
# Batch 1100/1482	 Loss 0.133362 (0.055826)
# Batch 1200/1482	 Loss 0.115650 (0.055863)
# Batch 1300/1482	 Loss 0.100457 (0.056649)
# Batch 1400/1482	 Loss 0.061161 (0.056882)
# ==> Test ARPLoss
# Acc: 98.18841
#        TNR    AUROC  DTACC  AUIN   AUOUT
# Bas     4.987 49.995 50.000 49.987 49.987
# Acc (%): 98.188	 AUROC (%): 49.995	 OSCR (%): 49.655
# ==> Epoch 47/100
# Batch 100/1482	 Loss 0.009653 (0.052557)
# Batch 200/1482	 Loss 0.070646 (0.052906)
# Batch 300/1482	 Loss 0.002649 (0.052206)
# Batch 400/1482	 Loss 0.002481 (0.053223)
# Batch 500/1482	 Loss 0.081569 (0.053744)
# Batch 600/1482	 Loss 0.000569 (0.053765)
# Batch 700/1482	 Loss 0.001268 (0.053717)
# Batch 800/1482	 Loss 0.088522 (0.053616)
# Batch 900/1482	 Loss 0.036145 (0.053227)
# Batch 1000/1482	 Loss 0.039711 (0.052510)
# Batch 1100/1482	 Loss 0.091897 (0.053824)
# Batch 1400/1482	 Loss 0.355173 (0.053234)
# ==> Test ARPLoss
# Acc: 98.02632
#        TNR    AUROC  DTACC  AUIN   AUOUT
# Bas     4.987 49.995 50.000 49.987 49.987
# Acc (%): 98.026	 AUROC (%): 49.995	 OSCR (%): 49.661
# ==> Epoch 48/100
# Batch 100/1482	 Loss 0.117105 (0.061229)
# Batch 200/1482	 Loss 0.005366 (0.056349)
# Batch 300/1482	 Loss 0.096323 (0.056320)
# Batch 400/1482	 Loss 0.003083 (0.054663)
# Batch 500/1482	 Loss 0.103577 (0.055017)
# Batch 600/1482	 Loss 0.055082 (0.054213)
# Batch 700/1482	 Loss 0.029630 (0.053749)
# Batch 800/1482	 Loss 0.043217 (0.054281)

# %%
# !zip -r '/home/ec2-user/SageMaker/ARPL/ARPL_models_1.zip' '/home/ec2-user/SageMaker/ARPL/log/models/vialytics_traffic_signs/checkpoints/'
# Out:
# updating: home/ec2-user/SageMaker/ARPL/log/models/vialytics_traffic_signs/checkpoints/ (stored 0%)
# updating: home/ec2-user/SageMaker/ARPL/log/models/vialytics_traffic_signs/checkpoints/96_98.169_.pth (deflated 7%)
# updating: home/ec2-user/SageMaker/ARPL/log/models/vialytics_traffic_signs/checkpoints/53_97.988_.pth (deflated 7%)
# updating: home/ec2-user/SageMaker/ARPL/log/models/vialytics_traffic_signs/checkpoints/10_74.733__criterion.pth (deflated 11%)
# updating: home/ec2-user/SageMaker/ARPL/log/models/vialytics_traffic_signs/checkpoints/83_98.198_.pth (deflated 7%)
# updating: home/ec2-user/SageMaker/ARPL/log/models/vialytics_traffic_signs/checkpoints/4_77.136_.pth (deflated 7%)
# updating: home/ec2-user/SageMaker/ARPL/log/models/vialytics_traffic_signs/checkpoints/98_98.16__criterion.pth (deflated 15%)
# updating: home/ec2-user/SageMaker/ARPL/log/models/vialytics_traffic_signs/checkpoints/13_92.553__criterion.pth (deflated 12%)
# updating: home/ec2-user/SageMaker/ARPL/log/models/vialytics_traffic_signs/checkpoints/31_97.702_.pth (deflated 7%)
# updating: home/ec2-user/SageMaker/ARPL/log/models/vialytics_traffic_signs/checkpoints/43_97.988_.pth (deflated 7%)
# updating: home/ec2-user/SageMaker/ARPL/log/models/vialytics_traffic_signs/checkpoints/15_92.248_.pth (deflated 7%)
# updating: home/ec2-user/SageMaker/ARPL/log/models/vialytics_traffic_signs/checkpoints/20_93.955_.pth (deflated 7%)
# updating: home/ec2-user/SageMaker/ARPL/log/models/vialytics_traffic_signs/checkpoints/16_91.447__criterion.pth (deflated 12%)
# updating: home/ec2-user/SageMaker/ARPL/log/models/vialytics_traffic_signs/checkpoints/99_98.169__criterion.pth (deflated 15%)
# updating: home/ec2-user/SageMaker/ARPL/log/models/vialytics_traffic_signs/checkpoints/78_98.169__criterion.pth (deflated 15%)
# updating: home/ec2-user/SageMaker/ARPL/log/models/vialytics_traffic_signs/checkpoints/71_98.188_.pth (deflated 7%)
# updating: home/ec2-user/SageMaker/ARPL/log/models/vialytics_traffic_signs/checkpoints/47_98.16_.pth (deflated 7%)
# updating: home/ec2-user/SageMaker/ARPL/log/models/vialytics_traffic_signs/checkpoints/98_98.16_.pth (deflated 7%)
# updating: home/ec2-user/SageMaker/ARPL/log/models/vialytics_traffic_signs/checkpoints/82_98.169__criterion.pth (deflated 15%)
# updating: home/ec2-user/SageMaker/ARPL/log/models/vialytics_traffic_signs/checkpoints/84_98.16_.pth (deflated 7%)
# updating: home/ec2-user/SageMaker/ARPL/log/models/vialytics_traffic_signs/checkpoints/86_98.274_.pth (deflated 7%)
# updating: home/ec2-user/SageMaker/ARPL/log/models/vialytics_traffic_signs/checkpoints/49_98.169__criterion.pth (deflated 14%)
# updating: home/ec2-user/SageMaker/ARPL/log/models/vialytics_traffic_signs/checkpoints/45_98.188_.pth (deflated 7%)
# updating: home/ec2-user/SageMaker/ARPL/log/models/vialytics_traffic_signs/checkpoints/77_98.198__criterion.pth (deflated 15%)
# updating: home/ec2-user/SageMaker/ARPL/log/models/vialytics_traffic_signs/checkpoints/81_98.188_.pth (deflated 7%)
# updating: home/ec2-user/SageMaker/ARPL/log/models/vialytics_traffic_signs/checkpoints/92_98.188__criterion.pth (deflated 15%)
# updating: home/ec2-user/SageMaker/ARPL/log/models/vialytics_traffic_signs/checkpoints/12_87.767__criterion.pth (deflated 11%)
# updating: home/ec2-user/SageMaker/ARPL/log/models/vialytics_traffic_signs/checkpoints/72_98.16__criterion.pth (deflated 15%)
# updating: home/ec2-user/SageMaker/ARPL/log/models/vialytics_traffic_signs/checkpoints/94_98.169_.pth (deflated 7%)
# updating: home/ec2-user/SageMaker/ARPL/log/models/vialytics_traffic_signs/checkpoints/85_98.236__criterion.pth (deflated 15%)
# updating: home/ec2-user/SageMaker/ARPL/log/models/vialytics_traffic_signs/checkpoints/33_97.836__criterion.pth (deflated 13%)
# updating: home/ec2-user/SageMaker/ARPL/log/models/vialytics_traffic_signs/checkpoints/2_78.576__criterion.pth (deflated 8%)
# updating: home/ec2-user/SageMaker/ARPL/log/models/vialytics_traffic_signs/checkpoints/7_89.502_.pth (deflated 7%)
# updating: home/ec2-user/SageMaker/ARPL/log/models/vialytics_traffic_signs/checkpoints/90_98.207__criterion.pth (deflated 15%)
# updating: home/ec2-user/SageMaker/ARPL/log/models/vialytics_traffic_signs/checkpoints/61_98.217_.pth (deflated 7%)
# updating: home/ec2-user/SageMaker/ARPL/log/models/vialytics_traffic_signs/checkpoints/31_97.702__criterion.pth (deflated 13%)
# updating: home/ec2-user/SageMaker/ARPL/log/models/vialytics_traffic_signs/checkpoints/78_98.169_.pth (deflated 7%)
# updating: home/ec2-user/SageMaker/ARPL/log/models/vialytics_traffic_signs/checkpoints/26_94.794__criterion.pth (deflated 13%)
# updating: home/ec2-user/SageMaker/ARPL/log/models/vialytics_traffic_signs/checkpoints/29_92.039_.pth (deflated 7%)
# updating: home/ec2-user/SageMaker/ARPL/log/models/vialytics_traffic_signs/checkpoints/42_97.921__criterion.pth (deflated 14%)
# updating: home/ec2-user/SageMaker/ARPL/log/models/vialytics_traffic_signs/checkpoints/88_98.131__criterion.pth (deflated 15%)
# updating: home/ec2-user/SageMaker/ARPL/log/models/vialytics_traffic_signs/checkpoints/67_98.198__criterion.pth (deflated 15%)
# updating: home/ec2-user/SageMaker/ARPL/log/models/vialytics_traffic_signs/checkpoints/69_98.15_.pth (deflated 7%)
# updating: home/ec2-user/SageMaker/ARPL/log/models/vialytics_traffic_signs/checkpoints/10_74.733_.pth (deflated 7%)
# updating: home/ec2-user/SageMaker/ARPL/log/models/vialytics_traffic_signs/checkpoints/48_98.198_.pth (deflated 7%)
# updating: home/ec2-user/SageMaker/ARPL/log/models/vialytics_traffic_signs/checkpoints/52_97.845_.pth (deflated 7%)
# updating: home/ec2-user/SageMaker/ARPL/log/models/vialytics_traffic_signs/checkpoints/38_97.626_.pth (deflated 7%)
# updating: home/ec2-user/SageMaker/ARPL/log/models/vialytics_traffic_signs/checkpoints/41_98.093_.pth (deflated 7%)
# updating: home/ec2-user/SageMaker/ARPL/log/models/vialytics_traffic_signs/checkpoints/90_98.207_.pth (deflated 7%)
# updating: home/ec2-user/SageMaker/ARPL/log/models/vialytics_traffic_signs/checkpoints/81_98.188__criterion.pth (deflated 15%)
# updating: home/ec2-user/SageMaker/ARPL/log/models/vialytics_traffic_signs/checkpoints/30_97.54_.pth (deflated 7%)
# updating: home/ec2-user/SageMaker/ARPL/log/models/vialytics_traffic_signs/checkpoints/68_98.103__criterion.pth (deflated 15%)
# updating: home/ec2-user/SageMaker/ARPL/log/models/vialytics_traffic_signs/checkpoints/17_93.221_.pth (deflated 7%)
# updating: home/ec2-user/SageMaker/ARPL/log/models/vialytics_traffic_signs/checkpoints/17_93.221__criterion.pth (deflated 12%)
# updating: home/ec2-user/SageMaker/ARPL/log/models/vialytics_traffic_signs/checkpoints/26_94.794_.pth (deflated 7%)
# updating: home/ec2-user/SageMaker/ARPL/log/models/vialytics_traffic_signs/checkpoints/63_98.084_.pth (deflated 7%)
# updating: home/ec2-user/SageMaker/ARPL/log/models/vialytics_traffic_signs/checkpoints/66_98.084_.pth (deflated 7%)
# updating: home/ec2-user/SageMaker/ARPL/log/models/vialytics_traffic_signs/checkpoints/50_98.15_.pth (deflated 7%)
# updating: home/ec2-user/SageMaker/ARPL/log/models/vialytics_traffic_signs/checkpoints/3_62.176__criterion.pth (deflated 9%)
# updating: home/ec2-user/SageMaker/ARPL/log/models/vialytics_traffic_signs/checkpoints/71_98.188__criterion.pth (deflated 15%)
# updating: home/ec2-user/SageMaker/ARPL/log/models/vialytics_traffic_signs/checkpoints/62_98.227_.pth (deflated 7%)
# updating: home/ec2-user/SageMaker/ARPL/log/models/vialytics_traffic_signs/checkpoints/28_93.926_.pth (deflated 7%)
# updating: home/ec2-user/SageMaker/ARPL/log/models/vialytics_traffic_signs/checkpoints/75_98.15_.pth (deflated 7%)
# updating: home/ec2-user/SageMaker/ARPL/log/models/vialytics_traffic_signs/checkpoints/82_98.169_.pth (deflated 7%)
# updating: home/ec2-user/SageMaker/ARPL/log/models/vialytics_traffic_signs/checkpoints/69_98.15__criterion.pth (deflated 15%)
# updating: home/ec2-user/SageMaker/ARPL/log/models/vialytics_traffic_signs/checkpoints/61_98.217__criterion.pth (deflated 15%)
# updating: home/ec2-user/SageMaker/ARPL/log/models/vialytics_traffic_signs/checkpoints/73_98.16__criterion.pth (deflated 15%)
# updating: home/ec2-user/SageMaker/ARPL/log/models/vialytics_traffic_signs/checkpoints/75_98.15__criterion.pth (deflated 15%)
# updating: home/ec2-user/SageMaker/ARPL/log/models/vialytics_traffic_signs/checkpoints/94_98.169__criterion.pth (deflated 15%)
# updating: home/ec2-user/SageMaker/ARPL/log/models/vialytics_traffic_signs/checkpoints/79_98.131__criterion.pth (deflated 15%)
# updating: home/ec2-user/SageMaker/ARPL/log/models/vialytics_traffic_signs/checkpoints/20_93.955__criterion.pth (deflated 12%)
# updating: home/ec2-user/SageMaker/ARPL/log/models/vialytics_traffic_signs/checkpoints/70_98.169__criterion.pth (deflated 15%)
# updating: home/ec2-user/SageMaker/ARPL/log/models/vialytics_traffic_signs/checkpoints/36_97.826__criterion.pth (deflated 14%)
# updating: home/ec2-user/SageMaker/ARPL/log/models/vialytics_traffic_signs/checkpoints/60_98.198__criterion.pth (deflated 15%)
# updating: home/ec2-user/SageMaker/ARPL/log/models/vialytics_traffic_signs/checkpoints/42_97.921_.pth (deflated 7%)
# updating: home/ec2-user/SageMaker/ARPL/log/models/vialytics_traffic_signs/checkpoints/9_89.092__criterion.pth (deflated 11%)
# updating: home/ec2-user/SageMaker/ARPL/log/models/vialytics_traffic_signs/checkpoints/73_98.16_.pth (deflated 7%)
# updating: home/ec2-user/SageMaker/ARPL/log/models/vialytics_traffic_signs/checkpoints/36_97.826_.pth (deflated 7%)
# updating: home/ec2-user/SageMaker/ARPL/log/models/vialytics_traffic_signs/checkpoints/68_98.103_.pth (deflated 7%)
# updating: home/ec2-user/SageMaker/ARPL/log/models/vialytics_traffic_signs/checkpoints/96_98.169__criterion.pth (deflated 15%)
# updating: home/ec2-user/SageMaker/ARPL/log/models/vialytics_traffic_signs/checkpoints/29_92.039__criterion.pth (deflated 13%)
# updating: home/ec2-user/SageMaker/ARPL/log/models/vialytics_traffic_signs/checkpoints/84_98.16__criterion.pth (deflated 15%)
# updating: home/ec2-user/SageMaker/ARPL/log/models/vialytics_traffic_signs/checkpoints/8_90.589__criterion.pth (deflated 10%)
# updating: home/ec2-user/SageMaker/ARPL/log/models/vialytics_traffic_signs/checkpoints/46_98.026__criterion.pth (deflated 14%)
# updating: home/ec2-user/SageMaker/ARPL/log/models/vialytics_traffic_signs/checkpoints/44_97.941__criterion.pth (deflated 14%)
# updating: home/ec2-user/SageMaker/ARPL/log/models/vialytics_traffic_signs/checkpoints/25_94.441_.pth (deflated 7%)
# updating: home/ec2-user/SageMaker/ARPL/log/models/vialytics_traffic_signs/checkpoints/85_98.236_.pth (deflated 7%)
# updating: home/ec2-user/SageMaker/ARPL/log/models/vialytics_traffic_signs/checkpoints/46_98.026_.pth (deflated 7%)
# updating: home/ec2-user/SageMaker/ARPL/log/models/vialytics_traffic_signs/checkpoints/0_40.322__criterion.pth (deflated 8%)
# updating: home/ec2-user/SageMaker/ARPL/log/models/vialytics_traffic_signs/checkpoints/95_98.16__criterion.pth (deflated 15%)
# updating: home/ec2-user/SageMaker/ARPL/log/models/vialytics_traffic_signs/checkpoints/76_98.198__criterion.pth (deflated 15%)
# updating: home/ec2-user/SageMaker/ARPL/log/models/vialytics_traffic_signs/checkpoints/56_97.626__criterion.pth (deflated 15%)
# updating: home/ec2-user/SageMaker/ARPL/log/models/vialytics_traffic_signs/checkpoints/48_98.198__criterion.pth (deflated 14%)
# updating: home/ec2-user/SageMaker/ARPL/log/models/vialytics_traffic_signs/checkpoints/13_92.553_.pth (deflated 7%)
# updating: home/ec2-user/SageMaker/ARPL/log/models/vialytics_traffic_signs/checkpoints/43_97.988__criterion.pth (deflated 14%)
# updating: home/ec2-user/SageMaker/ARPL/log/models/vialytics_traffic_signs/checkpoints/3_62.176_.pth (deflated 7%)
# updating: home/ec2-user/SageMaker/ARPL/log/models/vialytics_traffic_signs/checkpoints/74_98.179__criterion.pth (deflated 15%)
# updating: home/ec2-user/SageMaker/ARPL/log/models/vialytics_traffic_signs/checkpoints/89_98.169_.pth (deflated 7%)
# updating: home/ec2-user/SageMaker/ARPL/log/models/vialytics_traffic_signs/checkpoints/64_98.198_.pth (deflated 7%)
# updating: home/ec2-user/SageMaker/ARPL/log/models/vialytics_traffic_signs/checkpoints/87_98.16__criterion.pth (deflated 15%)
# updating: home/ec2-user/SageMaker/ARPL/log/models/vialytics_traffic_signs/checkpoints/34_97.893_.pth (deflated 7%)
# updating: home/ec2-user/SageMaker/ARPL/log/models/vialytics_traffic_signs/checkpoints/37_98.103__criterion.pth (deflated 14%)
# updating: home/ec2-user/SageMaker/ARPL/log/models/vialytics_traffic_signs/checkpoints/55_98.15__criterion.pth (deflated 15%)
# updating: home/ec2-user/SageMaker/ARPL/log/models/vialytics_traffic_signs/checkpoints/54_98.055__criterion.pth (deflated 14%)
# updating: home/ec2-user/SageMaker/ARPL/log/models/vialytics_traffic_signs/checkpoints/65_98.112__criterion.pth (deflated 15%)
# updating: home/ec2-user/SageMaker/ARPL/log/models/vialytics_traffic_signs/checkpoints/5_79.844__criterion.pth (deflated 9%)
# updating: home/ec2-user/SageMaker/ARPL/log/models/vialytics_traffic_signs/checkpoints/5_79.844_.pth (deflated 7%)
# updating: home/ec2-user/SageMaker/ARPL/log/models/vialytics_traffic_signs/checkpoints/11_90.98__criterion.pth (deflated 11%)
# updating: home/ec2-user/SageMaker/ARPL/log/models/vialytics_traffic_signs/checkpoints/32_97.788__criterion.pth (deflated 13%)
# updating: home/ec2-user/SageMaker/ARPL/log/models/vialytics_traffic_signs/checkpoints/80_98.141_.pth (deflated 7%)
# updating: home/ec2-user/SageMaker/ARPL/log/models/vialytics_traffic_signs/checkpoints/8_90.589_.pth (deflated 7%)
# updating: home/ec2-user/SageMaker/ARPL/log/models/vialytics_traffic_signs/checkpoints/35_98.064_.pth (deflated 7%)
# updating: home/ec2-user/SageMaker/ARPL/log/models/vialytics_traffic_signs/checkpoints/64_98.198__criterion.pth (deflated 15%)
# updating: home/ec2-user/SageMaker/ARPL/log/models/vialytics_traffic_signs/checkpoints/37_98.103_.pth (deflated 7%)
# updating: home/ec2-user/SageMaker/ARPL/log/models/vialytics_traffic_signs/checkpoints/18_93.354__criterion.pth (deflated 12%)
# updating: home/ec2-user/SageMaker/ARPL/log/models/vialytics_traffic_signs/checkpoints/14_93.812__criterion.pth (deflated 12%)
# updating: home/ec2-user/SageMaker/ARPL/log/models/vialytics_traffic_signs/checkpoints/83_98.198__criterion.pth (deflated 15%)
# updating: home/ec2-user/SageMaker/ARPL/log/models/vialytics_traffic_signs/checkpoints/23_94.727_.pth (deflated 7%)
# updating: home/ec2-user/SageMaker/ARPL/log/models/vialytics_traffic_signs/checkpoints/35_98.064__criterion.pth (deflated 14%)
# updating: home/ec2-user/SageMaker/ARPL/log/models/vialytics_traffic_signs/checkpoints/59_98.246__criterion.pth (deflated 15%)
# updating: home/ec2-user/SageMaker/ARPL/log/models/vialytics_traffic_signs/checkpoints/60_98.198_.pth (deflated 7%)
# updating: home/ec2-user/SageMaker/ARPL/log/models/vialytics_traffic_signs/checkpoints/53_97.988__criterion.pth (deflated 15%)
# updating: home/ec2-user/SageMaker/ARPL/log/models/vialytics_traffic_signs/checkpoints/6_84.725__criterion.pth (deflated 10%)
# updating: home/ec2-user/SageMaker/ARPL/log/models/vialytics_traffic_signs/checkpoints/15_92.248__criterion.pth (deflated 12%)
# updating: home/ec2-user/SageMaker/ARPL/log/models/vialytics_traffic_signs/checkpoints/7_89.502__criterion.pth (deflated 10%)
# updating: home/ec2-user/SageMaker/ARPL/log/models/vialytics_traffic_signs/checkpoints/25_94.441__criterion.pth (deflated 13%)
# updating: home/ec2-user/SageMaker/ARPL/log/models/vialytics_traffic_signs/checkpoints/21_91.114_.pth (deflated 7%)
# updating: home/ec2-user/SageMaker/ARPL/log/models/vialytics_traffic_signs/checkpoints/72_98.16_.pth (deflated 7%)
# updating: home/ec2-user/SageMaker/ARPL/log/models/vialytics_traffic_signs/checkpoints/39_98.141_.pth (deflated 7%)
# updating: home/ec2-user/SageMaker/ARPL/log/models/vialytics_traffic_signs/checkpoints/41_98.093__criterion.pth (deflated 14%)
# updating: home/ec2-user/SageMaker/ARPL/log/models/vialytics_traffic_signs/checkpoints/33_97.836_.pth (deflated 7%)
# updating: home/ec2-user/SageMaker/ARPL/log/models/vialytics_traffic_signs/checkpoints/40_97.95__criterion.pth (deflated 14%)
# updating: home/ec2-user/SageMaker/ARPL/log/models/vialytics_traffic_signs/checkpoints/91_98.179_.pth (deflated 7%)
# updating: home/ec2-user/SageMaker/ARPL/log/models/vialytics_traffic_signs/checkpoints/97_98.16_.pth (deflated 7%)
# updating: home/ec2-user/SageMaker/ARPL/log/models/vialytics_traffic_signs/checkpoints/55_98.15_.pth (deflated 7%)
# updating: home/ec2-user/SageMaker/ARPL/log/models/vialytics_traffic_signs/checkpoints/21_91.114__criterion.pth (deflated 13%)
# updating: home/ec2-user/SageMaker/ARPL/log/models/vialytics_traffic_signs/checkpoints/77_98.198_.pth (deflated 7%)
# updating: home/ec2-user/SageMaker/ARPL/log/models/vialytics_traffic_signs/checkpoints/27_93.841__criterion.pth (deflated 13%)
# updating: home/ec2-user/SageMaker/ARPL/log/models/vialytics_traffic_signs/checkpoints/70_98.169_.pth (deflated 7%)
# updating: home/ec2-user/SageMaker/ARPL/log/models/vialytics_traffic_signs/checkpoints/97_98.16__criterion.pth (deflated 15%)
# updating: home/ec2-user/SageMaker/ARPL/log/models/vialytics_traffic_signs/checkpoints/95_98.16_.pth (deflated 7%)
# updating: home/ec2-user/SageMaker/ARPL/log/models/vialytics_traffic_signs/checkpoints/23_94.727__criterion.pth (deflated 13%)
# updating: home/ec2-user/SageMaker/ARPL/log/models/vialytics_traffic_signs/checkpoints/62_98.227__criterion.pth (deflated 15%)
# updating: home/ec2-user/SageMaker/ARPL/log/models/vialytics_traffic_signs/checkpoints/93_98.141_.pth (deflated 7%)
# updating: home/ec2-user/SageMaker/ARPL/log/models/vialytics_traffic_signs/checkpoints/40_97.95_.pth (deflated 7%)
# updating: home/ec2-user/SageMaker/ARPL/log/models/vialytics_traffic_signs/checkpoints/63_98.084__criterion.pth (deflated 15%)
# updating: home/ec2-user/SageMaker/ARPL/log/models/vialytics_traffic_signs/checkpoints/76_98.198_.pth (deflated 7%)
# updating: home/ec2-user/SageMaker/ARPL/log/models/vialytics_traffic_signs/checkpoints/56_97.626_.pth (deflated 7%)
# updating: home/ec2-user/SageMaker/ARPL/log/models/vialytics_traffic_signs/checkpoints/19_90.322__criterion.pth (deflated 13%)
# updating: home/ec2-user/SageMaker/ARPL/log/models/vialytics_traffic_signs/checkpoints/49_98.169_.pth (deflated 7%)
# updating: home/ec2-user/SageMaker/ARPL/log/models/vialytics_traffic_signs/checkpoints/58_98.16__criterion.pth (deflated 15%)
# updating: home/ec2-user/SageMaker/ARPL/log/models/vialytics_traffic_signs/checkpoints/1_55.349__criterion.pth (deflated 8%)
# updating: home/ec2-user/SageMaker/ARPL/log/models/vialytics_traffic_signs/checkpoints/79_98.131_.pth (deflated 7%)
# updating: home/ec2-user/SageMaker/ARPL/log/models/vialytics_traffic_signs/checkpoints/51_98.322__criterion.pth (deflated 14%)
# updating: home/ec2-user/SageMaker/ARPL/log/models/vialytics_traffic_signs/checkpoints/34_97.893__criterion.pth (deflated 13%)
# updating: home/ec2-user/SageMaker/ARPL/log/models/vialytics_traffic_signs/checkpoints/44_97.941_.pth (deflated 7%)
# updating: home/ec2-user/SageMaker/ARPL/log/models/vialytics_traffic_signs/checkpoints/16_91.447_.pth (deflated 7%)
# updating: home/ec2-user/SageMaker/ARPL/log/models/vialytics_traffic_signs/checkpoints/22_95.099_.pth (deflated 7%)
# updating: home/ec2-user/SageMaker/ARPL/log/models/vialytics_traffic_signs/checkpoints/30_97.54__criterion.pth (deflated 13%)
# updating: home/ec2-user/SageMaker/ARPL/log/models/vialytics_traffic_signs/checkpoints/57_97.693_.pth (deflated 7%)
# updating: home/ec2-user/SageMaker/ARPL/log/models/vialytics_traffic_signs/checkpoints/47_98.16__criterion.pth (deflated 14%)
# updating: home/ec2-user/SageMaker/ARPL/log/models/vialytics_traffic_signs/checkpoints/45_98.188__criterion.pth (deflated 14%)
# updating: home/ec2-user/SageMaker/ARPL/log/models/vialytics_traffic_signs/checkpoints/6_84.725_.pth (deflated 7%)
# updating: home/ec2-user/SageMaker/ARPL/log/models/vialytics_traffic_signs/checkpoints/39_98.141__criterion.pth (deflated 14%)
# updating: home/ec2-user/SageMaker/ARPL/log/models/vialytics_traffic_signs/checkpoints/28_93.926__criterion.pth (deflated 13%)
# updating: home/ec2-user/SageMaker/ARPL/log/models/vialytics_traffic_signs/checkpoints/80_98.141__criterion.pth (deflated 15%)
# updating: home/ec2-user/SageMaker/ARPL/log/models/vialytics_traffic_signs/checkpoints/51_98.322_.pth (deflated 7%)
# updating: home/ec2-user/SageMaker/ARPL/log/models/vialytics_traffic_signs/checkpoints/59_98.246_.pth (deflated 7%)
# updating: home/ec2-user/SageMaker/ARPL/log/models/vialytics_traffic_signs/checkpoints/93_98.141__criterion.pth (deflated 15%)
# updating: home/ec2-user/SageMaker/ARPL/log/models/vialytics_traffic_signs/checkpoints/38_97.626__criterion.pth (deflated 14%)
# updating: home/ec2-user/SageMaker/ARPL/log/models/vialytics_traffic_signs/checkpoints/4_77.136__criterion.pth (deflated 9%)
# updating: home/ec2-user/SageMaker/ARPL/log/models/vialytics_traffic_signs/checkpoints/24_92.725__criterion.pth (deflated 13%)
# updating: home/ec2-user/SageMaker/ARPL/log/models/vialytics_traffic_signs/checkpoints/87_98.16_.pth (deflated 7%)
# updating: home/ec2-user/SageMaker/ARPL/log/models/vialytics_traffic_signs/checkpoints/11_90.98_.pth (deflated 7%)
# updating: home/ec2-user/SageMaker/ARPL/log/models/vialytics_traffic_signs/checkpoints/0_40.322_.pth (deflated 8%)
# updating: home/ec2-user/SageMaker/ARPL/log/models/vialytics_traffic_signs/checkpoints/32_97.788_.pth (deflated 7%)
# updating: home/ec2-user/SageMaker/ARPL/log/models/vialytics_traffic_signs/checkpoints/58_98.16_.pth (deflated 7%)
# updating: home/ec2-user/SageMaker/ARPL/log/models/vialytics_traffic_signs/checkpoints/12_87.767_.pth (deflated 7%)
# updating: home/ec2-user/SageMaker/ARPL/log/models/vialytics_traffic_signs/checkpoints/52_97.845__criterion.pth (deflated 14%)
# updating: home/ec2-user/SageMaker/ARPL/log/models/vialytics_traffic_signs/checkpoints/74_98.179_.pth (deflated 7%)
# updating: home/ec2-user/SageMaker/ARPL/log/models/vialytics_traffic_signs/checkpoints/14_93.812_.pth (deflated 7%)
# updating: home/ec2-user/SageMaker/ARPL/log/models/vialytics_traffic_signs/checkpoints/27_93.841_.pth (deflated 7%)
# updating: home/ec2-user/SageMaker/ARPL/log/models/vialytics_traffic_signs/checkpoints/2_78.576_.pth (deflated 7%)
# updating: home/ec2-user/SageMaker/ARPL/log/models/vialytics_traffic_signs/checkpoints/99_98.169_.pth (deflated 7%)
# updating: home/ec2-user/SageMaker/ARPL/log/models/vialytics_traffic_signs/checkpoints/86_98.274__criterion.pth (deflated 15%)
# updating: home/ec2-user/SageMaker/ARPL/log/models/vialytics_traffic_signs/checkpoints/57_97.693__criterion.pth (deflated 15%)
# updating: home/ec2-user/SageMaker/ARPL/log/models/vialytics_traffic_signs/checkpoints/92_98.188_.pth (deflated 7%)
# updating: home/ec2-user/SageMaker/ARPL/log/models/vialytics_traffic_signs/checkpoints/67_98.198_.pth (deflated 7%)
# updating: home/ec2-user/SageMaker/ARPL/log/models/vialytics_traffic_signs/checkpoints/91_98.179__criterion.pth (deflated 15%)
# updating: home/ec2-user/SageMaker/ARPL/log/models/vialytics_traffic_signs/checkpoints/1_55.349_.pth (deflated 8%)
# updating: home/ec2-user/SageMaker/ARPL/log/models/vialytics_traffic_signs/checkpoints/19_90.322_.pth (deflated 7%)
# updating: home/ec2-user/SageMaker/ARPL/log/models/vialytics_traffic_signs/checkpoints/18_93.354_.pth (deflated 7%)
# updating: home/ec2-user/SageMaker/ARPL/log/models/vialytics_traffic_signs/checkpoints/24_92.725_.pth (deflated 7%)
# updating: home/ec2-user/SageMaker/ARPL/log/models/vialytics_traffic_signs/checkpoints/54_98.055_.pth (deflated 7%)
# updating: home/ec2-user/SageMaker/ARPL/log/models/vialytics_traffic_signs/checkpoints/50_98.15__criterion.pth (deflated 15%)
# updating: home/ec2-user/SageMaker/ARPL/log/models/vialytics_traffic_signs/checkpoints/9_89.092_.pth (deflated 7%)
# updating: home/ec2-user/SageMaker/ARPL/log/models/vialytics_traffic_signs/checkpoints/89_98.169__criterion.pth (deflated 15%)
# updating: home/ec2-user/SageMaker/ARPL/log/models/vialytics_traffic_signs/checkpoints/65_98.112_.pth (deflated 7%)
# updating: home/ec2-user/SageMaker/ARPL/log/models/vialytics_traffic_signs/checkpoints/88_98.131_.pth (deflated 7%)
# updating: home/ec2-user/SageMaker/ARPL/log/models/vialytics_traffic_signs/checkpoints/66_98.084__criterion.pth (deflated 15%)
# updating: home/ec2-user/SageMaker/ARPL/log/models/vialytics_traffic_signs/checkpoints/22_95.099__criterion.pth (deflated 13%)

# %% [markdown]
# # Only evaluation

# %%
net, criterion = load_networks(net, model_path, file_name, criterion=criterion)
results = test(net, criterion, testloader, outloader, epoch=0, **options)
print("Acc (%): {:.3f}\t AUROC (%): {:.3f}\t OSCR (%): {:.3f}\t".format(results['ACC'], results['AUROC'], results['OSCR']))
